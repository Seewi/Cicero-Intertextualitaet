# %%
import re
import pandas as pd

# %%
briefe = pd.read_csv("data/cicero_letters.csv")

# %%
matcher = re.compile(r"\b[Homer*]|[Menand*]|[Strattis*]|[Epicharm*]|[Euripid*]|[R[h]int[h]on*]|[Enni*]|[Sophocl*]|[Lucili]|[Terent*]|[Plato*]|[Aeschyl*]|[Naevi*]|[Aristophan*]|[Archiloch*]|[Stati*]|[Trabea]|[Isocrat*]|[Thucydid*]|[Carnead*]|[Caecili]\b")
