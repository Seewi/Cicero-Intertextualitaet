# %%
import re
import pandas as pd

# %%
briefe = pd.read_csv("data/cicero_letters.csv")

# %%
matcher = re.compile(r"\b(?P<author>Homer\w*|Menand\w*|Strattis\w*|Epicharm\w*|Euripid\w*|Rh?inth?on\w*|Enni\w*|Sophocl\w*|Lucili\w*|Terent\w*|Plato\w*|Aeschyl\w*|Naevi\w*|Aristophan\w*|Archiloch\w*|Stati\w*|Trabea|Isocrat\w*|Thucydid\w*|Carnead\w*|Caecili)\b")
